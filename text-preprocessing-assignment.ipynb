# %% [markdown]
# # Assignment for Text preprocessing
#
# #### 1) Create your own dataset with columns : movie name , description and genre from TMDb website
# #### 2) Perform the necessary Text preprocessing on the description column

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import requests # This library is used to call APIs and get data from the internet
import pandas as pd
import time # Used to pause the program briefly so we don’t overload the API.

API_KEY = "8265bd1679663a7ea12ac168da84d2e8"

# Step 1: Get genre mapping

genre_url = f"https://api.themoviedb.org/3/genre/movie/list?api_key={API_KEY}&language=en-US"

genre_response = requests.get(genre_url).json() # Calls the API and converts the response into a Python dictionary.

# Map genre_id to genre_name
genre_dict = {genre['id']: genre['name'] for genre in genre_response['genres']}

#  Fetch all top-rated movies

all_data = []
total_pages = 471  
for page in range(1, total_pages + 1):
    movies_url = f"https://api.themoviedb.org/3/movie/top_rated?api_key={API_KEY}&language=en-US&page={page}"
    response = requests.get(movies_url).json()
    movies_list = response.get('results', [])
    
    for movie in movies_list:
        name = movie.get('title', "")
        description = movie.get('overview', "")
        genres = [genre_dict[g] for g in movie.get('genre_ids', [])]
        
        all_data.append({
            "movie_name": name,
            "description": description,
            "genre": ", ".join(genres)
        })
    
    print(f"Page {page} fetched, total movies collected: {len(all_data)}")
    time.sleep(0.3)  # To avoid hitting API rate limits

# Create DataFrame and save CSV

df = pd.DataFrame(all_data)
df.to_csv("/kaggle/working/top_rated_movies.csv", index=False)

print("Dataset saved as top_rated_movies.csv")
df.head(10)
# Out:
# Page 1 fetched, total movies collected: 20
# Page 2 fetched, total movies collected: 40
# Page 3 fetched, total movies collected: 60
# Page 4 fetched, total movies collected: 80
# Page 5 fetched, total movies collected: 100
# Page 6 fetched, total movies collected: 120
# Page 7 fetched, total movies collected: 140
# Page 8 fetched, total movies collected: 160
# Page 9 fetched, total movies collected: 180
# Page 10 fetched, total movies collected: 200
# Page 11 fetched, total movies collected: 220
# Page 12 fetched, total movies collected: 240
# Page 13 fetched, total movies collected: 260
# Page 14 fetched, total movies collected: 280
# Page 15 fetched, total movies collected: 300
# Page 16 fetched, total movies collected: 320
# Page 17 fetched, total movies collected: 340
# Page 18 fetched, total movies collected: 360
# Page 19 fetched, total movies collected: 380
# Page 20 fetched, total movies collected: 400
# Page 21 fetched, total movies collected: 420
# Page 22 fetched, total movies collected: 440
# Page 23 fetched, total movies collected: 460
# Page 24 fetched, total movies collected: 480
# Page 25 fetched, total movies collected: 500
# Page 26 fetched, total movies collected: 520
# Page 27 fetched, total movies collected: 540
# Page 28 fetched, total movies collected: 560
# Page 29 fetched, total movies collected: 580
# Page 30 fetched, total movies collected: 600
# Page 31 fetched, total movies collected: 620
# Page 32 fetched, total movies collected: 640
# Page 33 fetched, total movies collected: 660
# Page 34 fetched, total movies collected: 680
# Page 35 fetched, total movies collected: 700
# Page 36 fetched, total movies collected: 720
# Page 37 fetched, total movies collected: 740
# Page 38 fetched, total movies collected: 760
# Page 39 fetched, total movies collected: 780
# Page 40 fetched, total movies collected: 800
# Page 41 fetched, total movies collected: 820
# Page 42 fetched, total movies collected: 840
# Page 43 fetched, total movies collected: 860
# Page 44 fetched, total movies collected: 880
# Page 45 fetched, total movies collected: 900
# Page 46 fetched, total movies collected: 920
# Page 47 fetched, total movies collected: 940
# Page 48 fetched, total movies collected: 960
# Page 49 fetched, total movies collected: 980
# Page 50 fetched, total movies collected: 1000
# Page 51 fetched, total movies collected: 1020
# Page 52 fetched, total movies collected: 1040
# Page 53 fetched, total movies collected: 1060
# Page 54 fetched, total movies collected: 1080
# Page 55 fetched, total movies collected: 1100
# Page 56 fetched, total movies collected: 1120
# Page 57 fetched, total movies collected: 1140
# Page 58 fetched, total movies collected: 1160
# Page 59 fetched, total movies collected: 1180
# Page 60 fetched, total movies collected: 1200
# Page 61 fetched, total movies collected: 1220
# Page 62 fetched, total movies collected: 1240
# Page 63 fetched, total movies collected: 1260
# Page 64 fetched, total movies collected: 1280
# Page 65 fetched, total movies collected: 1300
# Page 66 fetched, total movies collected: 1320
# Page 67 fetched, total movies collected: 1340
# Page 68 fetched, total movies collected: 1360
# Page 69 fetched, total movies collected: 1380
# Page 70 fetched, total movies collected: 1400
# Page 71 fetched, total movies collected: 1420
# Page 72 fetched, total movies collected: 1440
# Page 73 fetched, total movies collected: 1460
# Page 74 fetched, total movies collected: 1480
# Page 75 fetched, total movies collected: 1500
# Page 76 fetched, total movies collected: 1520
# Page 77 fetched, total movies collected: 1540
# Page 78 fetched, total movies collected: 1560
# Page 79 fetched, total movies collected: 1580
# Page 80 fetched, total movies collected: 1600
# Page 81 fetched, total movies collected: 1620
# Page 82 fetched, total movies collected: 1640
# Page 83 fetched, total movies collected: 1660
# Page 84 fetched, total movies collected: 1680
# Page 85 fetched, total movies collected: 1700
# Page 86 fetched, total movies collected: 1720
# Page 87 fetched, total movies collected: 1740
# Page 88 fetched, total movies collected: 1760
# Page 89 fetched, total movies collected: 1780
# Page 90 fetched, total movies collected: 1800
# Page 91 fetched, total movies collected: 1820
# Page 92 fetched, total movies collected: 1840
# Page 93 fetched, total movies collected: 1860
# Page 94 fetched, total movies collected: 1880
# Page 95 fetched, total movies collected: 1900
# Page 96 fetched, total movies collected: 1920
# Page 97 fetched, total movies collected: 1940
# Page 98 fetched, total movies collected: 1960
# Page 99 fetched, total movies collected: 1980
# Page 100 fetched, total movies collected: 2000
# Page 101 fetched, total movies collected: 2020
# Page 102 fetched, total movies collected: 2040
# Page 103 fetched, total movies collected: 2060
# Page 104 fetched, total movies collected: 2080
# Page 105 fetched, total movies collected: 2100
# Page 106 fetched, total movies collected: 2120
# Page 107 fetched, total movies collected: 2140
# Page 108 fetched, total movies collected: 2160
# Page 109 fetched, total movies collected: 2180
# Page 110 fetched, total movies collected: 2200
# Page 111 fetched, total movies collected: 2220
# Page 112 fetched, total movies collected: 2240
# Page 113 fetched, total movies collected: 2260
# Page 114 fetched, total movies collected: 2280
# Page 115 fetched, total movies collected: 2300
# Page 116 fetched, total movies collected: 2320
# Page 117 fetched, total movies collected: 2340
# Page 118 fetched, total movies collected: 2360
# Page 119 fetched, total movies collected: 2380
# Page 120 fetched, total movies collected: 2400
# Page 121 fetched, total movies collected: 2420
# Page 122 fetched, total movies collected: 2440
# Page 123 fetched, total movies collected: 2460
# Page 124 fetched, total movies collected: 2480
# Page 125 fetched, total movies collected: 2500
# Page 126 fetched, total movies collected: 2520
# Page 127 fetched, total movies collected: 2540
# Page 128 fetched, total movies collected: 2560
# Page 129 fetched, total movies collected: 2580
# Page 130 fetched, total movies collected: 2600
# Page 131 fetched, total movies collected: 2620
# Page 132 fetched, total movies collected: 2640
# Page 133 fetched, total movies collected: 2660
# Page 134 fetched, total movies collected: 2680
# Page 135 fetched, total movies collected: 2700
# Page 136 fetched, total movies collected: 2720
# Page 137 fetched, total movies collected: 2740
# Page 138 fetched, total movies collected: 2760
# Page 139 fetched, total movies collected: 2780
# Page 140 fetched, total movies collected: 2800
# Page 141 fetched, total movies collected: 2820
# Page 142 fetched, total movies collected: 2840
# Page 143 fetched, total movies collected: 2860
# Page 144 fetched, total movies collected: 2880
# Page 145 fetched, total movies collected: 2900
# Page 146 fetched, total movies collected: 2920
# Page 147 fetched, total movies collected: 2940
# Page 148 fetched, total movies collected: 2960
# Page 149 fetched, total movies collected: 2980
# Page 150 fetched, total movies collected: 3000
# Page 151 fetched, total movies collected: 3020
# Page 152 fetched, total movies collected: 3040
# Page 153 fetched, total movies collected: 3060
# Page 154 fetched, total movies collected: 3080
# Page 155 fetched, total movies collected: 3100
# Page 156 fetched, total movies collected: 3120
# Page 157 fetched, total movies collected: 3140
# Page 158 fetched, total movies collected: 3160
# Page 159 fetched, total movies collected: 3180
# Page 160 fetched, total movies collected: 3200
# Page 161 fetched, total movies collected: 3220
# Page 162 fetched, total movies collected: 3240
# Page 163 fetched, total movies collected: 3260
# Page 164 fetched, total movies collected: 3280
# Page 165 fetched, total movies collected: 3300
# Page 166 fetched, total movies collected: 3320
# Page 167 fetched, total movies collected: 3340
# Page 168 fetched, total movies collected: 3360
# Page 169 fetched, total movies collected: 3380
# Page 170 fetched, total movies collected: 3400
# Page 171 fetched, total movies collected: 3420
# Page 172 fetched, total movies collected: 3440
# Page 173 fetched, total movies collected: 3460
# Page 174 fetched, total movies collected: 3480
# Page 175 fetched, total movies collected: 3500
# Page 176 fetched, total movies collected: 3520
# Page 177 fetched, total movies collected: 3540
# Page 178 fetched, total movies collected: 3560
# Page 179 fetched, total movies collected: 3580
# Page 180 fetched, total movies collected: 3600
# Page 181 fetched, total movies collected: 3620
# Page 182 fetched, total movies collected: 3640
# Page 183 fetched, total movies collected: 3660
# Page 184 fetched, total movies collected: 3680
# Page 185 fetched, total movies collected: 3700
# Page 186 fetched, total movies collected: 3720
# Page 187 fetched, total movies collected: 3740
# Page 188 fetched, total movies collected: 3760
# Page 189 fetched, total movies collected: 3780
# Page 190 fetched, total movies collected: 3800
# Page 191 fetched, total movies collected: 3820
# Page 192 fetched, total movies collected: 3840
# Page 193 fetched, total movies collected: 3860
# Page 194 fetched, total movies collected: 3880
# Page 195 fetched, total movies collected: 3900
# Page 196 fetched, total movies collected: 3920
# Page 197 fetched, total movies collected: 3940
# Page 198 fetched, total movies collected: 3960
# Page 199 fetched, total movies collected: 3980
# Page 200 fetched, total movies collected: 4000
# Page 201 fetched, total movies collected: 4020
# Page 202 fetched, total movies collected: 4040
# Page 203 fetched, total movies collected: 4060
# Page 204 fetched, total movies collected: 4080
# Page 205 fetched, total movies collected: 4100
# Page 206 fetched, total movies collected: 4120
# Page 207 fetched, total movies collected: 4140
# Page 208 fetched, total movies collected: 4160
# Page 209 fetched, total movies collected: 4180
# Page 210 fetched, total movies collected: 4200
# Page 211 fetched, total movies collected: 4220
# Page 212 fetched, total movies collected: 4240
# Page 213 fetched, total movies collected: 4260
# Page 214 fetched, total movies collected: 4280
# Page 215 fetched, total movies collected: 4300
# Page 216 fetched, total movies collected: 4320
# Page 217 fetched, total movies collected: 4340
# Page 218 fetched, total movies collected: 4360
# Page 219 fetched, total movies collected: 4380
# Page 220 fetched, total movies collected: 4400
# Page 221 fetched, total movies collected: 4420
# Page 222 fetched, total movies collected: 4440
# Page 223 fetched, total movies collected: 4460
# Page 224 fetched, total movies collected: 4480
# Page 225 fetched, total movies collected: 4500
# Page 226 fetched, total movies collected: 4520
# Page 227 fetched, total movies collected: 4540
# Page 228 fetched, total movies collected: 4560
# Page 229 fetched, total movies collected: 4580
# Page 230 fetched, total movies collected: 4600
# Page 231 fetched, total movies collected: 4620
# Page 232 fetched, total movies collected: 4640
# Page 233 fetched, total movies collected: 4660
# Page 234 fetched, total movies collected: 4680
# Page 235 fetched, total movies collected: 4700
# Page 236 fetched, total movies collected: 4720
# Page 237 fetched, total movies collected: 4740
# Page 238 fetched, total movies collected: 4760
# Page 239 fetched, total movies collected: 4780
# Page 240 fetched, total movies collected: 4800
# Page 241 fetched, total movies collected: 4820
# Page 242 fetched, total movies collected: 4840
# Page 243 fetched, total movies collected: 4860
# Page 244 fetched, total movies collected: 4880
# Page 245 fetched, total movies collected: 4900
# Page 246 fetched, total movies collected: 4920
# Page 247 fetched, total movies collected: 4940
# Page 248 fetched, total movies collected: 4960
# Page 249 fetched, total movies collected: 4980
# Page 250 fetched, total movies collected: 5000
# Page 251 fetched, total movies collected: 5020
# Page 252 fetched, total movies collected: 5040
# Page 253 fetched, total movies collected: 5060
# Page 254 fetched, total movies collected: 5080
# Page 255 fetched, total movies collected: 5100
# Page 256 fetched, total movies collected: 5120
# Page 257 fetched, total movies collected: 5140
# Page 258 fetched, total movies collected: 5160
# Page 259 fetched, total movies collected: 5180
# Page 260 fetched, total movies collected: 5200
# Page 261 fetched, total movies collected: 5220
# Page 262 fetched, total movies collected: 5240
# Page 263 fetched, total movies collected: 5260
# Page 264 fetched, total movies collected: 5280
# Page 265 fetched, total movies collected: 5300
# Page 266 fetched, total movies collected: 5320
# Page 267 fetched, total movies collected: 5340
# Page 268 fetched, total movies collected: 5360
# Page 269 fetched, total movies collected: 5380
# Page 270 fetched, total movies collected: 5400
# Page 271 fetched, total movies collected: 5420
# Page 272 fetched, total movies collected: 5440
# Page 273 fetched, total movies collected: 5460
# Page 274 fetched, total movies collected: 5480
# Page 275 fetched, total movies collected: 5500
# Page 276 fetched, total movies collected: 5520
# Page 277 fetched, total movies collected: 5540
# Page 278 fetched, total movies collected: 5560
# Page 279 fetched, total movies collected: 5580
# Page 280 fetched, total movies collected: 5600
# Page 281 fetched, total movies collected: 5620
# Page 282 fetched, total movies collected: 5640
# Page 283 fetched, total movies collected: 5660
# Page 284 fetched, total movies collected: 5680
# Page 285 fetched, total movies collected: 5700
# Page 286 fetched, total movies collected: 5720
# Page 287 fetched, total movies collected: 5740
# Page 288 fetched, total movies collected: 5760
# Page 289 fetched, total movies collected: 5780
# Page 290 fetched, total movies collected: 5800
# Page 291 fetched, total movies collected: 5820
# Page 292 fetched, total movies collected: 5840
# Page 293 fetched, total movies collected: 5860
# Page 294 fetched, total movies collected: 5880
# Page 295 fetched, total movies collected: 5900
# Page 296 fetched, total movies collected: 5920
# Page 297 fetched, total movies collected: 5940
# Page 298 fetched, total movies collected: 5960
# Page 299 fetched, total movies collected: 5980
# Page 300 fetched, total movies collected: 6000
# Page 301 fetched, total movies collected: 6020
# Page 302 fetched, total movies collected: 6040
# Page 303 fetched, total movies collected: 6060
# Page 304 fetched, total movies collected: 6080
# Page 305 fetched, total movies collected: 6100
# Page 306 fetched, total movies collected: 6120
# Page 307 fetched, total movies collected: 6140
# Page 308 fetched, total movies collected: 6160
# Page 309 fetched, total movies collected: 6180
# Page 310 fetched, total movies collected: 6200
# Page 311 fetched, total movies collected: 6220
# Page 312 fetched, total movies collected: 6240
# Page 313 fetched, total movies collected: 6260
# Page 314 fetched, total movies collected: 6280
# Page 315 fetched, total movies collected: 6300
# Page 316 fetched, total movies collected: 6320
# Page 317 fetched, total movies collected: 6340
# Page 318 fetched, total movies collected: 6360
# Page 319 fetched, total movies collected: 6380
# Page 320 fetched, total movies collected: 6400
# Page 321 fetched, total movies collected: 6420
# Page 322 fetched, total movies collected: 6440
# Page 323 fetched, total movies collected: 6460
# Page 324 fetched, total movies collected: 6480
# Page 325 fetched, total movies collected: 6500
# Page 326 fetched, total movies collected: 6520
# Page 327 fetched, total movies collected: 6540
# Page 328 fetched, total movies collected: 6560
# Page 329 fetched, total movies collected: 6580
# Page 330 fetched, total movies collected: 6600
# Page 331 fetched, total movies collected: 6620
# Page 332 fetched, total movies collected: 6640
# Page 333 fetched, total movies collected: 6660
# Page 334 fetched, total movies collected: 6680
# Page 335 fetched, total movies collected: 6700
# Page 336 fetched, total movies collected: 6720
# Page 337 fetched, total movies collected: 6740
# Page 338 fetched, total movies collected: 6760
# Page 339 fetched, total movies collected: 6780
# Page 340 fetched, total movies collected: 6800
# Page 341 fetched, total movies collected: 6820
# Page 342 fetched, total movies collected: 6840
# Page 343 fetched, total movies collected: 6860
# Page 344 fetched, total movies collected: 6880
# Page 345 fetched, total movies collected: 6900
# Page 346 fetched, total movies collected: 6920
# Page 347 fetched, total movies collected: 6940
# Page 348 fetched, total movies collected: 6960
# Page 349 fetched, total movies collected: 6980
# Page 350 fetched, total movies collected: 7000
# Page 351 fetched, total movies collected: 7020
# Page 352 fetched, total movies collected: 7040
# Page 353 fetched, total movies collected: 7060
# Page 354 fetched, total movies collected: 7080
# Page 355 fetched, total movies collected: 7100
# Page 356 fetched, total movies collected: 7120
# Page 357 fetched, total movies collected: 7140
# Page 358 fetched, total movies collected: 7160
# Page 359 fetched, total movies collected: 7180
# Page 360 fetched, total movies collected: 7200
# Page 361 fetched, total movies collected: 7220
# Page 362 fetched, total movies collected: 7240
# Page 363 fetched, total movies collected: 7260
# Page 364 fetched, total movies collected: 7280
# Page 365 fetched, total movies collected: 7300
# Page 366 fetched, total movies collected: 7320
# Page 367 fetched, total movies collected: 7340
# Page 368 fetched, total movies collected: 7360
# Page 369 fetched, total movies collected: 7380
# Page 370 fetched, total movies collected: 7400
# Page 371 fetched, total movies collected: 7420
# Page 372 fetched, total movies collected: 7440
# Page 373 fetched, total movies collected: 7460
# Page 374 fetched, total movies collected: 7480
# Page 375 fetched, total movies collected: 7500
# Page 376 fetched, total movies collected: 7520
# Page 377 fetched, total movies collected: 7540
# Page 378 fetched, total movies collected: 7560
# Page 379 fetched, total movies collected: 7580
# Page 380 fetched, total movies collected: 7600
# Page 381 fetched, total movies collected: 7620
# Page 382 fetched, total movies collected: 7640
# Page 383 fetched, total movies collected: 7660
# Page 384 fetched, total movies collected: 7680
# Page 385 fetched, total movies collected: 7700
# Page 386 fetched, total movies collected: 7720
# Page 387 fetched, total movies collected: 7740
# Page 388 fetched, total movies collected: 7760
# Page 389 fetched, total movies collected: 7780
# Page 390 fetched, total movies collected: 7800
# Page 391 fetched, total movies collected: 7820
# Page 392 fetched, total movies collected: 7840
# Page 393 fetched, total movies collected: 7860
# Page 394 fetched, total movies collected: 7880
# Page 395 fetched, total movies collected: 7900
# Page 396 fetched, total movies collected: 7920
# Page 397 fetched, total movies collected: 7940
# Page 398 fetched, total movies collected: 7960
# Page 399 fetched, total movies collected: 7980
# Page 400 fetched, total movies collected: 8000
# Page 401 fetched, total movies collected: 8020
# Page 402 fetched, total movies collected: 8040
# Page 403 fetched, total movies collected: 8060
# Page 404 fetched, total movies collected: 8080
# Page 405 fetched, total movies collected: 8100
# Page 406 fetched, total movies collected: 8120
# Page 407 fetched, total movies collected: 8140
# Page 408 fetched, total movies collected: 8160
# Page 409 fetched, total movies collected: 8180
# Page 410 fetched, total movies collected: 8200
# Page 411 fetched, total movies collected: 8220
# Page 412 fetched, total movies collected: 8240
# Page 413 fetched, total movies collected: 8260
# Page 414 fetched, total movies collected: 8280
# Page 415 fetched, total movies collected: 8300
# Page 416 fetched, total movies collected: 8320
# Page 417 fetched, total movies collected: 8340
# Page 418 fetched, total movies collected: 8360
# Page 419 fetched, total movies collected: 8380
# Page 420 fetched, total movies collected: 8400
# Page 421 fetched, total movies collected: 8420
# Page 422 fetched, total movies collected: 8440
# Page 423 fetched, total movies collected: 8460
# Page 424 fetched, total movies collected: 8480
# Page 425 fetched, total movies collected: 8500
# Page 426 fetched, total movies collected: 8520
# Page 427 fetched, total movies collected: 8540
# Page 428 fetched, total movies collected: 8560
# Page 429 fetched, total movies collected: 8580
# Page 430 fetched, total movies collected: 8600
# Page 431 fetched, total movies collected: 8620
# Page 432 fetched, total movies collected: 8640
# Page 433 fetched, total movies collected: 8660
# Page 434 fetched, total movies collected: 8680
# Page 435 fetched, total movies collected: 8700
# Page 436 fetched, total movies collected: 8720
# Page 437 fetched, total movies collected: 8740
# Page 438 fetched, total movies collected: 8760
# Page 439 fetched, total movies collected: 8780
# Page 440 fetched, total movies collected: 8800
# Page 441 fetched, total movies collected: 8820
# Page 442 fetched, total movies collected: 8840
# Page 443 fetched, total movies collected: 8860
# Page 444 fetched, total movies collected: 8880
# Page 445 fetched, total movies collected: 8900
# Page 446 fetched, total movies collected: 8920
# Page 447 fetched, total movies collected: 8940
# Page 448 fetched, total movies collected: 8960
# Page 449 fetched, total movies collected: 8980
# Page 450 fetched, total movies collected: 9000
# Page 451 fetched, total movies collected: 9020
# Page 452 fetched, total movies collected: 9040
# Page 453 fetched, total movies collected: 9060
# Page 454 fetched, total movies collected: 9080
# Page 455 fetched, total movies collected: 9100
# Page 456 fetched, total movies collected: 9120
# Page 457 fetched, total movies collected: 9140
# Page 458 fetched, total movies collected: 9160
# Page 459 fetched, total movies collected: 9180
# Page 460 fetched, total movies collected: 9200
# Page 461 fetched, total movies collected: 9220
# Page 462 fetched, total movies collected: 9240
# Page 463 fetched, total movies collected: 9260
# Page 464 fetched, total movies collected: 9280
# Page 465 fetched, total movies collected: 9300
# Page 466 fetched, total movies collected: 9320
# Page 467 fetched, total movies collected: 9340
# Page 468 fetched, total movies collected: 9360
# Page 469 fetched, total movies collected: 9380
# Page 470 fetched, total movies collected: 9400
# Page 471 fetched, total movies collected: 9420
# Dataset saved as top_rated_movies.csv
#                     movie_name  \
# 0     The Shawshank Redemption
# 1                The Godfather
# 2        The Godfather Part II
# 3             Schindler's List
# 4                 12 Angry Men
# 5                Spirited Away
# 6              The Dark Knight
# 7  Dilwale Dulhania Le Jayenge
# 8               The Green Mile
# 9                     Parasite
#
#                                          description  \
# 0  Imprisoned in the 1940s for the double murder ...
# 1  Spanning the years 1945 to 1955, a chronicle o...
# 2  In the continuing saga of the Corleone crime f...
# 3  The true story of how businessman Oskar Schind...
# 4  The defense and the prosecution have rested an...
# 5  A young girl, Chihiro, becomes trapped in a st...
# 6  Batman raises the stakes in his war on crime. ...
# 7  Raj is a rich, carefree, happy-go-lucky second...
# 8  A supernatural tale set on death row in a Sout...
# 9  All unemployed, Ki-taek's family takes peculia...
#
#                             genre
# 0                    Drama, Crime
# 1                    Drama, Crime
# 2                    Drama, Crime
# 3             Drama, History, War
# 4                           Drama
# 5      Animation, Family, Fantasy
# 6  Drama, Action, Crime, Thriller
# 7          Comedy, Drama, Romance
# 8           Fantasy, Drama, Crime
# 9         Comedy, Thriller, Drama

# %%
df
# Out:
#                          movie_name  \
# 0          The Shawshank Redemption
# 1                     The Godfather
# 2             The Godfather Part II
# 3                  Schindler's List
# 4                      12 Angry Men
# ...                             ...
# 9415                     White Girl
# 9416              Playing for Keeps
# 9417                  Captive State
# 9418  The Texas Chainsaw Massacre 2
# 9419                        Damaged
#
#                                             description  \
# 0     Imprisoned in the 1940s for the double murder ...
# 1     Spanning the years 1945 to 1955, a chronicle o...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     The defense and the prosecution have rested an...
# ...                                                 ...
# 9415  Summer, New York City. A college girl falls ha...
# 9416  A former sports star who's fallen on hard time...
# 9417  Nearly a decade after occupation by an extrate...
# 9418  A radio host is victimised by the notorious ca...
# 9419  A Chicago detective travels to Scotland after ...
#
#                                   genre
# 0                          Drama, Crime
# 1                          Drama, Crime
# 2                          Drama, Crime
# 3                   Drama, History, War
# 4                                 Drama
# ...                                 ...
# 9415                              Drama
# 9416                    Comedy, Romance
# 9417  Science Fiction, Action, Thriller
# 9418                     Horror, Comedy
# 9419     Action, Drama, Thriller, Crime
#
# [9420 rows x 3 columns]

# %%
df['description']
# Out:
# 0       Imprisoned in the 1940s for the double murder ...
# 1       Spanning the years 1945 to 1955, a chronicle o...
# 2       In the continuing saga of the Corleone crime f...
# 3       The true story of how businessman Oskar Schind...
# 4       The defense and the prosecution have rested an...
#                               ...
# 9415    Summer, New York City. A college girl falls ha...
# 9416    A former sports star who's fallen on hard time...
# 9417    Nearly a decade after occupation by an extrate...
# 9418    A radio host is victimised by the notorious ca...
# 9419    A Chicago detective travels to Scotland after ...
# Name: description, Length: 9420, dtype: object

# %%
# 1) lowercasing

df['description'] = df['description'].str.lower()
df['description']
# Out:
# 0       imprisoned in the 1940s for the double murder ...
# 1       spanning the years 1945 to 1955, a chronicle o...
# 2       in the continuing saga of the corleone crime f...
# 3       the true story of how businessman oskar schind...
# 4       the defense and the prosecution have rested an...
#                               ...
# 9415    summer, new york city. a college girl falls ha...
# 9416    a former sports star who's fallen on hard time...
# 9417    nearly a decade after occupation by an extrate...
# 9418    a radio host is victimised by the notorious ca...
# 9419    a chicago detective travels to scotland after ...
# Name: description, Length: 9420, dtype: object

# %%
# 2) Checking if the column has html tags or not

import re

def has_html(text):
    # Pattern checks for <tag> or </tag>
    html_pattern = re.compile(r'<.*?>')
    if pd.isna(text):  # Handle empty cells
        return False
    return bool(html_pattern.search(text))


# Add a new column that shows True if HTML is present
df['has_html'] = df['description'].apply(has_html)

# Count how many rows have HTML
html_count = df['has_html'].sum()
print(f"Number of rows with HTML tags: {html_count}")

# Show rows with HTML tags
df_with_html = df[df['has_html'] == True]
print(df_with_html)

## NO any html tag so no needed to remove
# Out:
# Number of rows with HTML tags: 0
# Empty DataFrame
# Columns: [movie_name, description, genre, has_html]
# Index: []

# %%
# 3) Removing Url , but first checking if there are urls or not

def has_url(text):
    
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    if pd.isna(text):  # Handle empty cells
        return False
    return bool(url_pattern.search(text))

# Add a new column that shows True if URL is present
df['has_url'] = df['description'].apply(has_url) # This creates a new column called has_url in your DataFrame.For each row, the value will be: True → if the description contains a URL and False → if it does not contain a URL

# Count how many rows have URLs
url_count = df['has_url'].sum()
print(f"Number of rows with URLs: {url_count}")

# Show rows with URLs
df_with_urls = df[df['has_url'] == True]
print(df_with_urls)


# there are no urls so no needed to remove
# Out:
# Number of rows with URLs: 0
# Empty DataFrame
# Columns: [movie_name, description, genre, has_html, has_url]
# Index: []

# %%
# 4) Removing Punctuations

import string
exclude = string.punctuation

def remove_punc(text):
    if pd.isna(text): # checks if a value is missing or “NaN” (Not a Number).
        return ""
    return text.translate(str.maketrans('', '', exclude)) # It will throw an error for the row where description is NaN because .translate() cannot be applied to NaN. so pd.isna() is used


df['description_clean'] = df['description'].apply(remove_punc)

df['description_clean']
# Out:
# 0       imprisoned in the 1940s for the double murder ...
# 1       spanning the years 1945 to 1955 a chronicle of...
# 2       in the continuing saga of the corleone crime f...
# 3       the true story of how businessman oskar schind...
# 4       the defense and the prosecution have rested an...
#                               ...
# 9415    summer new york city a college girl falls hard...
# 9416    a former sports star whos fallen on hard times...
# 9417    nearly a decade after occupation by an extrate...
# 9418    a radio host is victimised by the notorious ca...
# 9419    a chicago detective travels to scotland after ...
# Name: description_clean, Length: 9420, dtype: object

# %%
# 5) Chatwords handling

chatwords_dict = {
    'A3': 'Anytime, Anywhere, Anyplace',
    'ADIH': 'Another Day In Hell',
    'AFK': 'Away From Keyboard',
    'AFAIK': 'As Far As I Know',
    'ASAP': 'As Soon As Possible',
    'ASL': 'Age, Sex, Location',
    'ATK': 'At The Keyboard',
    'ATM': 'At The Moment',
    'BAE': 'Before Anyone Else',
    'BAK': 'Back At Keyboard',
    'BBL': 'Be Back Later',
    'BBS': 'Be Back Soon',
    'BFN': 'Bye For Now',
    'B4N': 'Bye For Now',
    'BRB': 'Be Right Back',
    'BRUH': 'Bro',
    'BRT': 'Be Right There',
    'BSAAW': 'Big Smile And A Wink',
    'BTW': 'By The Way',
    'BWL': 'Bursting With Laughter',
    'CSL': 'Can’t Stop Laughing',
    'CU': 'See You',
    'CUL8R': 'See You Later',
    'CYA': 'See You',
    'DM': 'Direct Message',
    'FAQ': 'Frequently Asked Questions',
    'FC': 'Fingers Crossed',
    'FIMH': 'Forever In My Heart',
    'FOMO': 'Fear Of Missing Out',
    'FR': 'For Real',
    'FWIW': "For What It's Worth",
    'FYP': 'For You Page',
    'FYI': 'For Your Information',
    'G9': 'Genius',
    'GAL': 'Get A Life',
    'GG': 'Good Game',
    'GMTA': 'Great Minds Think Alike',
    'GN': 'Good Night',
    'GOAT': 'Greatest Of All Time',
    'GR8': 'Great!',
    'HBD': 'Happy Birthday',
    'IC': 'I See',
    'ICQ': 'I Seek You',
    'IDC': 'I Don’t Care',
    'IDK': "I Don't Know",
    'IFYP': 'I Feel Your Pain',
    'ILU': 'I Love You',
    'ILY': 'I Love You',
    'IMHO': 'In My Honest/Humble Opinion',
    'IMU': 'I Miss You',
    'IMO': 'In My Opinion',
    'IOW': 'In Other Words',
    'IRL': 'In Real Life',
    'IYKYK': 'If You Know, You Know',
    'JK': 'Just Kidding',
    'KISS': 'Keep It Simple, Stupid',
    'L': 'Loss',
    'L8R': 'Later',
    'LDR': 'Long Distance Relationship',
    'LMK': 'Let Me Know',
    'LMAO': 'Laughing My A** Off',
    'LOL': 'Laughing Out Loud',
    'LTNS': 'Long Time No See',
    'M8': 'Mate',
    'MFW': 'My Face When',
    'MID': 'Mediocre',
    'MRW': 'My Reaction When',
    'MTE': 'My Thoughts Exactly',
    'NVM': 'Never Mind',
    'NRN': 'No Reply Necessary',
    'NPC': 'Non-Player Character',
    'OIC': 'Oh I See',
    'OP': 'Overpowered',
    'PITA': 'Pain In The A**',
    'POV': 'Point Of View',
    'PRT': 'Party',
    'PRW': 'Parents Are Watching',
    'ROFL': 'Rolling On The Floor Laughing',
    'ROFLOL': 'Rolling On The Floor Laughing Out Loud',
    'ROTFLMAO': 'Rolling On The Floor Laughing My A** Off',
    'RN': 'Right Now',
    'SK8': 'Skate',
    'STATS': 'Your Sex And Age',
    'SUS': 'Suspicious',
    'TBH': 'To Be Honest',
    'TFW': 'That Feeling When',
    'THX': 'Thank You',
    'TIME': 'Tears In My Eyes',
    'TLDR': 'Too Long, Didn’t Read',
    'TNTL': 'Trying Not To Laugh',
    'TTFN': 'Ta-Ta For Now!',
    'TTYL': 'Talk To You Later',
    'U': 'You',
    'U2': 'You Too',
    'U4E': 'Yours For Ever',
    'W': 'Win',
    'W8': 'Wait...',
    'WB': 'Welcome Back',
    'WTF': 'What The F**k',
    'WTG': 'Way To Go!',
    'WUF': 'Where Are You From?',
    'WYD': 'What You Doing?',
    'WYWH': 'Wish You Were Here',
    'ZZZ': 'Sleeping, Bored, Tired',
    'SMH': 'Shaking My Head',
    'AF': 'As F**k',
    'TMI': 'Too Much Information',
    'BFF': 'Best Friends Forever',
    'YOLO': 'You Only Live Once',
    'ICYMI': 'In Case You Missed It',
    'OTP': 'One True Pairing',
    'IKR': 'I Know, Right?',
    'NBD': 'No Big Deal',
    'FML': 'F**k My Life',
    'GTG': 'Got To Go',
    'IDTS': 'I Don’t Think So',
    'HBU': 'How About You?',
    'TTYT': 'Talk To You Tomorrow',
    'OMW': 'On My Way'
}

# %%
def replace_chatwords(text, chat_dict):
    if pd.isna(text):  # Handle missing values
        return ""
    words = text.split()  # Split text into words
    
    new_words = [chat_dict.get(word.upper(), word) for word in words]  # Replace if in dictionary

# chat_dict.get(key, default) means:Look for key in the dictionary , If found → return its value and If NOT found → return default , the default means the original word not found in the dictionary

    
    return " ".join(new_words)  # join() takes a list of words and combines (joins) them into one sentence, inserting a space " " between each word.

# %%
df['description_clean_chatwords'] = df['description_clean'].apply(lambda x: replace_chatwords(x, chatwords_dict))

df['description_clean_chatwords']
# Out:
# 0       imprisoned in the 1940s for the double murder ...
# 1       spanning the years 1945 to 1955 a chronicle of...
# 2       in the continuing saga of the corleone crime f...
# 3       the true story of how businessman oskar schind...
# 4       the defense and the prosecution have rested an...
#                               ...
# 9415    summer new york city a college girl falls hard...
# 9416    a former sports star whos fallen on hard times...
# 9417    nearly a decade after occupation by an extrate...
# 9418    a radio host is victimised by the notorious ca...
# 9419    a chicago detective travels to scotland after ...
# Name: description_clean_chatwords, Length: 9420, dtype: object

# %%
# 6) TMDB movie descriptions are written professionally.They almost never include emojis like 😂❤️🔥 , but just checking if there are emojis or not

df['has_emoji'] = df['description'].str.contains(r'[\U0001F600-\U0001F64F]', regex=True)

df['has_emoji'].sum()
# Out:
# 0

# %% [markdown]
# #### 7) Spelling correction slows processing and may distort movie titles or names like Thor” → corrected to “Thorn so not needed

# %%
# When you start ML modeling later: then first do tokenization and then lemmatization . Stemming is not necessary for movie description  as it Makes phrases less meaningful

# %%
# Tokenization
# Tokenization + Lemmatization → Done together in ONE step → Saved into ONE final column



import spacy
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])

def spacy_tokenize_lemmatize(text):
    if pd.isna(text) or text.strip() == "":
        return ""

    doc = nlp(text)  # contains tokenized words

    # It creates a cleaned, lemmatized list of words from the description by skipping spaces.
    tokens = [token.lemma_ for token in doc if not token.is_space]

    return " ".join(tokens)

df["description_final"] = df["description_clean_chatwords"].apply(spacy_tokenize_lemmatize)

df["description_final"]
# Out:
# 0       imprison in the 1940 for the double murder of ...
# 1       span the year 1945 to 1955 a chronicle of the ...
# 2       in the continue saga of the corleone crime fam...
# 3       the true story of how businessman oskar schind...
# 4       the defense and the prosecution have rest and ...
#                               ...
# 9415    summer new york city a college girl fall hard ...
# 9416    a former sport star who s fall on hard time st...
# 9417    nearly a decade after occupation by an extrate...
# 9418    a radio host be victimise by the notorious can...
# 9419    a chicago detective travel to scotland after a...
# Name: description_final, Length: 9420, dtype: object
